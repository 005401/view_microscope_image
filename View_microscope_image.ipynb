# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
from alvra_tools import *
# Out:
# [INFO][corrections] Numba not available, reverting to Numpy

# %%
#f = h5py.File('/sf/alvra/data/p17982/raw/camera_test/run_000001.BSREAD.h5_SARES11-XMI125-C4P1.h5')
#f = h5py.File('/sf/alvra/data/p17982/raw/jet_test/run_000007.BSREAD.h5_SARES11-XMI125-C4P1.h5')
f = h5py.File('/sf/alvra/data/p17982/raw/jet_test_100mbar/run_000040.BSREAD.h5_SARES11-XMI125-C4P1.h5')

imno += 1
xy = np.array(f['data/SARES11-XMI125-C4P1:FPICTURE/data'][imno,:,:])
# xyz = np.array(f['data/SARES11-XMI125-C4P1:FPICTURE/data'][:,:,:])
pid = f['data/SARES11-XMI125-C4P1:FPICTURE/pulse_id'][imno]

print('PulseID: {}\t\timno: {}'.format(pid,imno))
# print (xy.shape)
# print (xyz.shape)

print(np.min(xy))
print(np.max(xy))

plt.figure(figsize=(20,10))
plt.imshow(xy, cmap='gray', interpolation='none',origin= 'lower',vmax=20)
plt.xlabel('Pixel x')
plt.ylabel('Pixel y')
plt.show()
# Out:
# PulseID: 9878991080		imno: 24
# 0
# 25
